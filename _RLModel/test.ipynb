# %%
import asyncio
import py3gazebo.pygazebo
# Out:
# Traceback (most recent call last):
#
#   File ~/.pyenv/versions/gymnasium-3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3667 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[5], line 2
#     import py3gazebo.pygazebo
#
#   File ~/ws/PX4-Autopilot/_RLModel/py3gazebo/pygazebo/__init__.py:22
#     from .pygazebo import connect
#
#   File ~/ws/PX4-Autopilot/_RLModel/py3gazebo/pygazebo/pygazebo.py:251
#     future = asyncio.async(loop.sock_connect(self.socket, address))
#                      ^
# SyntaxError: invalid syntax
